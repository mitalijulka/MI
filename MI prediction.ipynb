# %%
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

df = pd.read_excel("/Users/Richard/Desktop/Queens_MFIT/867/a4/Myocardial infarction complications Database Lethal outcome.xlsx")

# %%
df.head()
df.describe()
# Out:
#                 ID          AGE          SEX     INF_ANAM    STENOK_AN  \
# count  1700.000000  1692.000000  1700.000000  1696.000000  1594.000000
# mean    850.500000    61.856974     0.626471     0.554835     2.316186
# std     490.892045    11.259936     0.483883     0.836801     2.440586
# min       1.000000    26.000000     0.000000     0.000000     0.000000
# 25%     425.750000    54.000000     0.000000     0.000000     0.000000
# 50%     850.500000    63.000000     1.000000     0.000000     1.000000
# 75%    1275.250000    70.000000     1.000000     1.000000     5.000000
# max    1700.000000    92.000000     1.000000     3.000000     6.000000
#
#          FK_STENOK     IBS_POST  IBS_NASL           GB   SIM_GIPERT  ...  \
# count  1627.000000  1649.000000  72.00000  1691.000000  1692.000000  ...
# mean      1.205286     1.160703   0.37500     1.393258     0.033688  ...
# std       1.040814     0.801400   0.48752     1.088803     0.180478  ...
# ...

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
top_col = ['AGE','ZSN_A','R_AB_3_n','ant_im','L_BLOOD','D_AD_ORIT','S_AD_ORIT','STENOK_AN','inf_im','NA_R_3_n','NITR_S',
           'ROE','S_AD_ORIT','lat_im','TIME_B_S','inf_im','K_BLOOD','ALT_BLOOD','LID_KB','ZSN_A','IBS_POST',
           'endocr_01','NOT_NA_3_n','NOT_NA_KB','NA_BLOOD']

top_df = df[top_col]

# %%
msno.matrix(top_df)
# Out:
# <AxesSubplot:>
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
msno.heatmap(top_df)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['AGE'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
ax = sns.boxplot(x='LET_IS', y='AGE', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
ax = sns.countplot(x='ZSN_A',hue='LET_IS',data = df)
ax.set_xticklabels(['no chronic heart failure', 'I stage','right ventricular systolic',
                    'left ventricular systolic','left and right'])
plt.show()

# %%
ax = sns.countplot(x='ZSN_A',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no chronic heart failure', 'I stage','right ventricular systolic',
                    'left ventricular systolic','left and right'])
plt.show()

# %%
ax = sns.countplot(x='R_AB_3_n',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['there is no relapse', 'only one','2 times','3 or more times'])
plt.show()

# %%
ax = sns.countplot(x='R_AB_3_n',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['there is no relapse', 'only one','2 times','3 or more times'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['L_BLOOD'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='L_BLOOD', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['D_AD_ORIT'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='D_AD_ORIT', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['S_AD_ORIT'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='S_AD_ORIT', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
ax = sns.countplot(x='STENOK_AN',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['never', 'during the last year','one year ago','two years ago','three years ago',
                    '4-5 years ago','more than 5 years ago'])
plt.show()

# %%
ax = sns.countplot(x='inf_im',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no infarct', 'QRS has no changes','QR-complex','Qr-complex','QS-complex'])
plt.show()

# %%
ax = sns.countplot(x='NA_R_3_n',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no', 'once','twice'])
plt.show()

# %%
ax = sns.countplot(x='NITR_S',hue='LET_IS',data = df)
ax.set_xticklabels(['yes', 'no'])
plt.show()

# %%
ax = sns.countplot(x='NITR_S',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['yes', 'no'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['ROE'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='ROE', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['S_AD_ORIT'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='S_AD_ORIT', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
ax = sns.countplot(x='lat_im',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no infarct', 'no changes','QR-complex','Qr-complex','QS-complex'])
plt.show()

# %%
ax = sns.countplot(x='TIME_B_S',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['less than 2h', '2-4h','4-6h','6-8h','8-12h','12-24h','more than 1d','more than 2d','more than 3d'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['K_BLOOD'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='K_BLOOD', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['ALT_BLOOD'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='ALT_BLOOD', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()

# %%
ax = sns.countplot(x='LID_KB',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no','yes'])
plt.show()

# %%
ax = sns.countplot(x='IBS_POST',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['there was no СHD','exertional angina pectoris','unstable angina pectoris'])
plt.show()

# %%
ax = sns.countplot(x='endocr_01',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no','yes'])
plt.show()

# %%
ax = sns.countplot(x='NOT_NA_3_n',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no','once','twice'])
plt.show()

# %%
ax = sns.countplot(x='NOT_NA_KB',hue='LET_IS',data = df[df['LET_IS'] != 0])
ax.set_xticklabels(['no','yes'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5),"font.size":15,'font.sans-serif':['SimHei'],"axes.titlesize":15,"axes.labelsize":15})
plt.title('distribution')
sns.set_color_codes("pastel")
sns.distplot(df['NA_BLOOD'],kde=True,bins=200, color="blue")
plt.show()
# Out:
# /Users/Richard/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(x='LET_IS', y='NA_BLOOD', data=df)
ax.set_xticklabels(['unknown', 'cardiogenic shock','pulmonary edema','myocardial rupture',
                    'congestive heart failure','thromboembolism','asystole','ventricular fibrillation'])
plt.show()
